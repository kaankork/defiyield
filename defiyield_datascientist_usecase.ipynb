# %% [markdown]
# # Use-Case for Data Scientist Interview at DeFiYield
# Created by Kaan Korkmaz.

# %% [markdown]
# Here is our Rect Database: https://defiyield.app/rekt-database
# Task:
# -  prepare the visualization of risk vectors and how it evolves over time?
# - Share a jupyter notebook (or equivalent) in case of this task.
#
# We expected just a few visualizations to highlight what are the most important insights from our database.

# %% [markdown]
# The API key: bad7014e-3fd4-473a-b981-1a5c2dd2d72e

# %% [markdown]
# The doc about the API:
# https://docs.defiyield.app/api/api

# %%
import json
import requests
import keyring
import pandas as pd
from bs4 import BeautifulSoup
import plotly.graph_objects as go

# %% [markdown]
# ## Data Collection

# %%
api_key = keyring.get_password('defiyield', 'api_key')
headers = {'X-Api-Key': api_key}      
query_url = 'https://public-api.defiyield.app/graphql/'

# %%
def create_body(page_number):
  def body(): """query {
      rekts(
        pageNumber:%s
        pageSize:50
        orderBy: {
          date: desc
        }
      ) {
        id
        projectName
        description
        date
        fundsLost
        fundsReturned
        category
        chaindIds
        issueType
      }
    }"""
    
  def create_body_w_pageNumber(page_number):
    body.__doc__
    body.__doc__ %= page_number
  
  body()
  create_body_w_pageNumber(page_number)
  return body.__doc__

# %%
data_list = []
for i in range(1, 27):
    print(i)
    body = create_body(i)
    
    response = requests.post(url=query_url,
                             json={'query': body},
                             headers=headers)
    
    data_list.append(response.json()["data"]["rekts"])

# %%
flat_list = [item for sublist in data_list for item in sublist]
df_rects = pd.DataFrame(flat_list)

# %% [markdown]
# ## Preprocessing

# %%
df_rects['fundsLost'] = pd.to_numeric(df_rects['fundsLost'])
df_rects['fundsReturned'] = pd.to_numeric(df_rects['fundsReturned'])
df_rects['date'] = pd.to_datetime(df_rects['date'])
df_rects.head()
# Out:
#      id       projectName                                        description  \
# 0  3320   Thoreum Finance  <p><strong>Quick Summary</strong></p><p>The Th...
# 1  3319   BONK Inu (Fake)  <p><strong>Quick Summary</strong></p><p>BONK I...
# 2  3321  OMNI Real Estate  <p><strong>Quick Summary</strong></p><p>The OM...
# 3  3316     Midas Capital  <p><strong>Quick Summary</strong></p><p>Midas ...
# 4  3315           LendHub  <p><strong>Quick Summary</strong></p><p>The Le...
#
#         date  fundsLost  fundsReturned               category chaindIds  \
# 0 2023-01-19     580000              0                  Other       [2]
# 1 2023-01-18     150000              0                  Token       [3]
# 2 2023-01-17      70000              0                    NFT       [2]
# 3 2023-01-15     650000              0  Borrowing and Lending       [3]
# 4 2023-01-12    6000000              0  Borrowing and Lending      [11]
#
#            issueType
# 0     Access Control
# 1            Rugpull
# 2              Other
# 3  Flash Loan Attack
# 4              Other

# %%
df_rects.to_csv('data/all_data.csv')

# %%
# Create df per issueType for visualization purposes
df_rects_issue_abandoned = df_rects[df_rects["issueType"] == "Abandoned"]
df_rects_issue_honeypot = df_rects[df_rects["issueType"] == "Honeypot"]
df_rects_issue_rugpull = df_rects[df_rects["issueType"] == "Rugpull"]
df_rects_issue_accesscontrol = df_rects[df_rects["issueType"] == "Access Control"]
df_rects_issue_phishing = df_rects[df_rects["issueType"] == "Phishing"]
df_rects_issue_flashloanattack = df_rects[df_rects["issueType"] == "Flash Loan Attack"]
df_rects_issue_reentrancy = df_rects[df_rects["issueType"] == "Reentrancy"]
df_rects_issue_oracleissue = df_rects[df_rects["issueType"] == "Oracle Issue"]
df_rects_issue_other = df_rects[df_rects["issueType"] == "Other"]

# %%
# Save
df_rects_issue_abandoned.to_csv('data/issue_abandoned.csv')
df_rects_issue_honeypot.to_csv('data/issue_honeypot.csv')
df_rects_issue_rugpull.to_csv('data/issue_rugpull.csv')
df_rects_issue_accesscontrol.to_csv('data/issue_accesscontrol.csv')
df_rects_issue_phishing.to_csv('data/issue_phishing.csv')
df_rects_issue_flashloanattack.to_csv('data/issue_flashloanattack.csv')
df_rects_issue_reentrancy.to_csv('data/issue_reentrancy.csv')
df_rects_issue_oracleissue.to_csv('data/issue_oracleissue.csv')
df_rects_issue_other.to_csv('data/issue_other.csv')

# %%
dfff_ = df_rects.resample(rule='M', on='date')['fundsLost'].sum().reset_index()

# %%
dfff = pd.DataFrame(dfff_, )
dfff.to_csv('data/grouped_by_day_sum_fundsLost.csv')

# %%
dfff.head()
# Out:
#         date  fundsLost
# 0 2011-06-30    8818300
# 1 2011-07-31     254100
# 2 2011-08-31     619000
# 3 2011-09-30      32800
# 4 2011-10-31      61120

# %%
df_groupby_date_issueType = df_rects.groupby(by=['date', 'issueType'], as_index=False)['fundsLost'].sum()
df_groupby_date_issueType.to_csv('data/grouped_by_date_issueType_sum_fundsLost.csv')

# %%
df_groupby_date_issueType = df_rects.groupby(by=['date', 'category'], as_index=False)['fundsLost'].sum()
df_groupby_date_issueType.to_csv('data/grouped_by_date_category_sum_fundsLost.csv')

# %%
df_groupby_date_issueType.head()
# Out:
#         date       issueType  fundsLost
# 0 2011-06-13           Other    8750000
# 1 2011-06-21           Other      68300
# 2 2011-07-01         Rugpull      18100
# 3 2011-07-26  Access Control     236000
# 4 2011-08-08         Rugpull     619000

# %%
df_groupby_date_issueType_pivoted = df_groupby_date_issueType.pivot(index='date', 
                                                                    columns='issueType', 
                                                                    values='fundsLost').fillna(0).rename_axis(None, axis=1)

# df_groupby_date_issueType_pivoted.columns=df_groupby_date_issueType_pivoted.columns.get_level_values(0)
# df_groupby_date_issueType_pivoted = df_groupby_date_issueType_pivoted.xs('issueType', axis=1, drop_level=True)

# %%
df_groupby_date_issueType_pivoted.to_csv('data/per_day_issueType.csv')

# %%
df_groupby_date_issueType_pivoted[0:40]
# Out:
#             Abandoned  Access Control  Flash Loan Attack  Honeypot  \
# date
# 2011-06-13        0.0             0.0                0.0       0.0
# 2011-06-21        0.0             0.0                0.0       0.0
# 2011-07-01        0.0             0.0                0.0       0.0
# 2011-07-26        0.0        236000.0                0.0       0.0
# 2011-08-08        0.0             0.0                0.0       0.0
# 2011-09-01        0.0             0.0                0.0       0.0
# 2011-10-05        0.0             0.0                0.0       0.0
# 2011-10-28        0.0             0.0                0.0       0.0
# 2012-03-01        0.0             0.0                0.0       0.0
# 2012-03-12        0.0             0.0                0.0       0.0
# 2012-04-11        0.0         15300.0                0.0       0.0
# 2012-05-11        0.0             0.0                0.0       0.0
# 2012-07-02        0.0             0.0                0.0       0.0
# 2012-07-04        0.0         12000.0                0.0       0.0
# 2012-07-13        0.0        303000.0                0.0       0.0
# 2012-09-05        0.0             0.0                0.0       0.0
# 2012-09-19        0.0             0.0                0.0       0.0
# 2012-09-28        0.0        113000.0                0.0       0.0
# 2012-10-13        0.0             0.0                0.0       0.0
# 2012-11-16        0.0             0.0                0.0       0.0
# 2013-02-13        0.0         50800.0                0.0       0.0
# 2013-03-10        0.0             0.0                0.0       0.0
# 2013-03-28        0.0             0.0                0.0       0.0
# 2013-04-01        0.0        169000.0                0.0       0.0
# 2013-04-19        0.0             0.0                0.0       0.0
# 2013-04-26        0.0        202000.0                0.0       0.0
# 2013-05-10        0.0        342000.0                0.0       0.0
# 2013-06-01        0.0        167000.0                0.0       0.0
# 2013-07-01        0.0             0.0                0.0       0.0
# 2013-07-15        0.0        123000.0                0.0       0.0
# 2013-10-01        0.0             0.0                0.0       0.0
# 2013-10-23        0.0        809000.0                0.0       0.0
# 2013-10-26        0.0             0.0                0.0       0.0
# 2013-11-11        0.0             0.0                0.0       0.0
# 2013-11-17        0.0             0.0                0.0       0.0
# 2013-11-29        0.0       6420000.0                0.0       0.0
# 2014-02-24        0.0             0.0                0.0       0.0
# 2014-03-02        0.0             0.0                0.0       0.0
# 2014-03-04        0.0             0.0                0.0       0.0
# 2014-03-15        0.0             0.0                0.0       0.0
#
#             Oracle Issue         Other  Phishing  Reentrancy    Rugpull
# date
# 2011-06-13           0.0  8.750000e+06       0.0         0.0        0.0
# 2011-06-21           0.0  6.830000e+04       0.0         0.0        0.0
# 2011-07-01           0.0  0.000000e+00       0.0         0.0    18100.0
# 2011-07-26           0.0  0.000000e+00       0.0         0.0        0.0
# 2011-08-08           0.0  0.000000e+00       0.0         0.0   619000.0
# 2011-09-01           0.0  0.000000e+00       0.0         0.0    32800.0
# 2011-10-05           0.0  5.310000e+04       0.0         0.0        0.0
# 2011-10-28           0.0  8.020000e+03       0.0         0.0        0.0
# 2012-03-01           0.0  0.000000e+00       0.0         0.0     6450.0
# 2012-03-12           0.0  2.280000e+05       0.0         0.0        0.0
# 2012-04-11           0.0  0.000000e+00       0.0         0.0        0.0
# 2012-05-11           0.0  8.700000e+04       0.0         0.0        0.0
# 2012-07-02           0.0  0.000000e+00       0.0         0.0  4630000.0
# 2012-07-04           0.0  0.000000e+00       0.0         0.0        0.0
# 2012-07-13           0.0  0.000000e+00       0.0         0.0        0.0
# 2012-09-05           0.0  2.510000e+05       0.0         0.0        0.0
# 2012-09-19           0.0  3.360000e+09       0.0         0.0        0.0
# 2012-09-28           0.0  0.000000e+00       0.0         0.0        0.0
# 2012-10-13           0.0  1.400000e+04       0.0         0.0        0.0
# 2012-11-16           0.0  3.920000e+04       0.0         0.0        0.0
# 2013-02-13           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-03-10           0.0  5.800000e+04       0.0         0.0        0.0
# 2013-03-28           0.0  3.700000e+05       0.0         0.0        0.0
# 2013-04-01           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-04-19           0.0  1.350000e+05       0.0         0.0        0.0
# 2013-04-26           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-05-10           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-06-01           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-07-01           0.0  5.450000e+05       0.0         0.0        0.0
# 2013-07-15           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-10-01           0.0  0.000000e+00       0.0         0.0   277000.0
# 2013-10-23           0.0  0.000000e+00       0.0         0.0        0.0
# 2013-10-26           0.0  0.000000e+00       0.0         0.0  4000000.0
# 2013-11-11           0.0  1.610000e+05       0.0         0.0        0.0
# 2013-11-17           0.0  6.000000e+05       0.0         0.0        0.0
# 2013-11-29           0.0  0.000000e+00       0.0         0.0        0.0
# 2014-02-24           0.0  4.730000e+08       0.0         0.0        0.0
# 2014-03-02           0.0  6.142980e+05       0.0         0.0        0.0
# 2014-03-04           0.0  6.560000e+04       0.0         0.0        0.0
# 2014-03-15           0.0  6.590000e+05       0.0         0.0        0.0

# %%
# df_groupby_date_issueType_pivoted = df_groupby_date_issueType_pivoted.set_index('date') 
df_groupby_date_issueType_pivoted_month = df_groupby_date_issueType_pivoted.groupby(pd.Grouper(freq='M')).aggregate('sum')
df_groupby_date_issueType_pivoted_month.to_csv('data/per_month_issueType.csv')

# %%
df_groupby_date_issueType_pivoted_month_count = df_groupby_date_issueType_pivoted.groupby(pd.Grouper(freq='M')).aggregate('count')

# %%
df_groupby_date_issueType_pivoted_month_count
# Out:
#             Abandoned  Access Control  Flash Loan Attack  Honeypot  \
# date
# 2011-06-30          2               2                  2         2
# 2011-07-31          2               2                  2         2
# 2011-08-31          1               1                  1         1
# 2011-09-30          1               1                  1         1
# 2011-10-31          2               2                  2         2
# ...               ...             ...                ...       ...
# 2022-09-30         19              19                 19        19
# 2022-10-31         25              25                 25        25
# 2022-11-30         16              16                 16        16
# 2022-12-31         15              15                 15        15
# 2023-01-31          7               7                  7         7
#
#             Oracle Issue  Other  Phishing  Reentrancy  Rugpull
# date
# 2011-06-30             2      2         2           2        2
# 2011-07-31             2      2         2           2        2
# 2011-08-31             1      1         1           1        1
# 2011-09-30             1      1         1           1        1
# 2011-10-31             2      2         2           2        2
# ...                  ...    ...       ...         ...      ...
# 2022-09-30            19     19        19          19       19
# 2022-10-31            25     25        25          25       25
# 2022-11-30            16     16        16          16       16
# 2022-12-31            15     15        15          15       15
# 2023-01-31             7      7         7           7        7
#
# [140 rows x 9 columns]

# %%
df_groupby_date_issueType_pivoted_month[df_groupby_date_issueType_pivoted_month.index == '2013-04-30']
# Out:
#             Abandoned  Access Control  Flash Loan Attack  Honeypot  \
# date
# 2013-04-30        0.0        371000.0                0.0       0.0
#
#             Oracle Issue     Other  Phishing  Reentrancy  Rugpull
# date
# 2013-04-30           0.0  135000.0       0.0         0.0      0.0

# %% [markdown]
# # Visualization

# %% [markdown]
# Show how risk vectors evolve over time.

# %%
import plotly.express as px
# df = px.data.stocks()
fig = px.line(df_rects, x="date", y=df_rects["fundsLost"],
            #   hover_data={"date": "|%B %d, %Y"},
              title='custom tick labels with ticklabelmode="period"')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y",
    ticklabelmode="period")
fig.show()

# %%
import plotly.express as px
# df = px.data.stocks()
fig = px.line(df_groupby_date_issueType_pivoted, x="date", y=df_groupby_date_issueType_pivoted['Abandoned'],
            #   hover_data={"date": "|%B %d, %Y"},
              title='custom tick labels with ticklabelmode="period"')
# fig.update_xaxes(
#     dtick="M1",
#     tickformat="%Y",
#     ticklabelmode="period")
fig.show()

# %%
fig = px.bar(df_groupby_date_issueType_pivoted_month, x="medal", y="count", color="nation", text="nation")
fig.show()

# %%
df = px.data.stocks()

# %%
df.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
import plotly.express as px

fig = px.bar(df_groupby_date_issueType_pivoted, 
              x=df_groupby_date_issueType_pivoted.index, 
              y=df_groupby_date_issueType_pivoted.columns,
            #   hover_data={"date": "|%B %d, %Y"},
              title='Issue Type Trend over Time')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y",
    ticklabelmode="period")
fig.show()

# %%
import plotly.express as px

wide_df = px.data.medals_wide()

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"], title="Wide-Form Input")
fig.show()

# %%
wide_df
# Out:
#         nation  gold  silver  bronze
# 0  South Korea    24      13      11
# 1        China    10      15       8
# 2       Canada     9      12      12

# %%
import plotly.express as px
fig = px.histogram(df_rects, x="date", color="issueType")
fig.show()

# %%
fig = px.histogram(df_rects, x="date", color="category").update_yaxes(categoryorder="total ascending")
fig.show()

# %%
df_rects.sort_values(["category", "issueType"])
# Out:
#         id                projectName  \
# 399   2691                    bZx (4)
# 875   2705                Wild Credit
# 897   2365                     EasyFi
# 3     3316              Midas Capital
# 21    3288           Lodestar Finance
# ...    ...                        ...
# 1199  2901                     Netbox
# 1240  2671                    OneCoin
# 1268  2955               BASIC-MINING
# 1286  2975  Bitcoin Savings and Trust
# 1290  2977                 Bitscalper
#
#                                             description       date  fundsLost  \
# 399   <p>The private key, controlling BSC and Polygo... 2021-11-05   47600000
# 875   <p>The attacker's address:<br>https://ethersca... 2021-05-27     611963
# 897   <p><strong>Quick Summary</strong></p><p>EasyFi... 2021-04-19   59000000
# 3     <p><strong>Quick Summary</strong></p><p>Midas ... 2023-01-15     650000
# 21    <p><strong>Quick Summary</strong></p><p>Lodest... 2022-12-10    5800000
# ...                                                 ...        ...        ...
# 1199  <p>The Etbox platform wallet was hacked, causi... 2019-03-24     132000
# 1240  <p>OneCoin was a Ponzi scheme that pulled in $... 2016-03-07    4000000
# 1268  <p>Mining company BASIC-MINING took advantage ... 2013-10-01     277000
# 1286  <p>Bitcoin Savings &amp; Trust (abbreviated as... 2012-07-02    4630000
# 1290  <p>Initially presented as a successful investm... 2012-03-01       6450
#
#       fundsReturned               category chaindIds          issueType  \
# 399               0  Borrowing and Lending    [2, 3]     Access Control
# 875          611963  Borrowing and Lending       [1]     Access Control
# 897               0  Borrowing and Lending       [1]     Access Control
# 3                 0  Borrowing and Lending       [3]  Flash Loan Attack
# 21                0  Borrowing and Lending       [5]  Flash Loan Attack
# ...             ...                    ...       ...                ...
# 1199              0                   None        []            Rugpull
# 1240              0                   None        []            Rugpull
# 1268              0                   None        []            Rugpull
# 1286              0                   None        []            Rugpull
# 1290              0                   None        []            Rugpull
#
#       percent_fundsLost
# 399            0.063841
# 875            0.000821
# 897            0.079130
# 3              0.000872
# 21             0.007779
# ...                 ...
# 1199           0.000177
# 1240           0.005365
# 1268           0.000372
# 1286           0.006210
# 1290           0.000009
#
# [1300 rows x 10 columns]

# %%
new_df = df_rects.groupby(by=["category", "issueType"]).aggregate('fundsLost').sum()
new_df.to_csv('data/heatmap.csv')

# %%
dfff = pd.read_csv('data/heatmap.csv')

# %%
dfff = dfff.sort_values(["category", "issueType"], ascending=False)

# %%
x_categories = dfff['issueType']
y_categories = dfff['category']

# %%
fig = go.Figure(data=go.Heatmap(
                   z=dfff['fundsLost'],
                   x=x_categories,
                   y=y_categories,
                   hoverongaps = False,
                   colorscale='balance'))

fig.layout.title = "Total Amount of Lost Funds ($)"
fig.layout.height = 1200
fig.layout.width = 1400
fig.update_xaxes(side="top")
fig.update_layout(xaxis=dict(showgrid=False),
              yaxis=dict(showgrid=False)
)

fig.show()

# %%
df_groupby_date_issueType.head()
# Out:
#         date       issueType  fundsLost
# 0 2011-06-13           Other    8750000
# 1 2011-06-21           Other      68300
# 2 2011-07-01         Rugpull      18100
# 3 2011-07-26  Access Control     236000
# 4 2011-08-08         Rugpull     619000

# %%
data_canada = px.data.gapminder().query("country == 'Canada'")

# %%
data_canada.dtypes
# fig = px.bar(data_canada, x='year', y='pop')
# fig.show()
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# iso_alpha     object
# iso_num        int64
# dtype: object

# %%
df_groupby_date_issueType['year'] = df_groupby_date_issueType['date'].dt.year

# %%
df_groupby_date_issueType
# Out:
#           date          issueType  fundsLost  year
# 0   2011-06-13              Other    8750000  2011
# 1   2011-06-21              Other      68300  2011
# 2   2011-07-01            Rugpull      18100  2011
# 3   2011-07-26     Access Control     236000  2011
# 4   2011-08-08            Rugpull     619000  2011
# ..         ...                ...        ...   ...
# 800 2023-01-12              Other    6000000  2023
# 801 2023-01-15  Flash Loan Attack     650000  2023
# 802 2023-01-17              Other      70000  2023
# 803 2023-01-18            Rugpull     150000  2023
# 804 2023-01-19     Access Control     580000  2023
#
# [805 rows x 4 columns]

# %%
fig = px.bar(df_groupby_date_issueType, x="year", y="fundsLost", color="issueType" ,title="Long-Form Input")
fig.show()

# %%
ig = go.Figure(data=go.Bar(x=df_groupby_date_issueType['date'].astype(dtype=str), 
                        y=df_groupby_date_issueType['fundsLost'],
                        marker_color='issueType', text="counts"))
fig.update_layout({"title": 'Tweets about Malioboro from Jan 2020 to Jan 2021',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total tweets"},
                   "showlegend": False})

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[252], line 1
# ----> 1 ig = go.Figure(data=go.Bar(x=df_groupby_date_issueType['date'].astype(dtype=str),
#       2                         y=df_groupby_date_issueType['fundsLost'],
#       3                         marker_color='issueType', text="counts"))
#       4 fig.update_layout({"title": 'Tweets about Malioboro from Jan 2020 to Jan 2021',
#       5                    "xaxis": {"title":"Months"},
#       6                    "yaxis": {"title":"Total tweets"},
#       7                    "showlegend": False})
#       9 fig.show()
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/graph_objs/_bar.py:3285, in Bar.__init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    3281 arg.pop("type", None)
#    3283 # Process unknown kwargs
#    3284 # ----------------------
# -> 3285 self._process_kwargs(**dict(arg, **kwargs))
#    3287 # Reset skip_invalid
#    3288 # ------------------
#    3289 self._skip_invalid = False
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:4364, in BasePlotlyType._process_kwargs(self, **kwargs)
#    4361 err = _check_path_in_prop_tree(self, k, error_cast=ValueError)
#    4362 if err is None:
#    4363     # e.g. underscore kwargs like marker_line_color
# -> 4364     self[k] = v
#    4365 elif not self._validate:
#    4366     # Set extra property as-is
#    4367     self[k] = v
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:4891, in BasePlotlyType.__setitem__(self, prop, value)
#    4887     res = res[p]
#    4889 res._validate = self._validate
# -> 4891 res[prop[-1]] = value
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4847         self._set_array_prop(prop, value)
#    4849     # ### Handle simple property ###
#    4850     else:
# -> 4851         self._set_prop(prop, value)
#    4852 else:
#    4853     # Make sure properties dict is initialized
#    4854     self._init_props()
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:5195, in BasePlotlyType._set_prop(self, prop, val)
#    5193         return
#    5194     else:
# -> 5195         raise err
#    5197 # val is None
#    5198 # -----------
#    5199 if val is None:
#    5200     # Check if we should send null update
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:5190, in BasePlotlyType._set_prop(self, prop, val)
#    5187 validator = self._get_validator(prop)
#    5189 try:
# -> 5190     val = validator.validate_coerce(val)
#    5191 except ValueError as err:
#    5192     if self._skip_invalid:
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/_plotly_utils/basevalidators.py:1375, in ColorValidator.validate_coerce(self, v, should_raise)
#    1373     validated_v = self.vc_scalar(v)
#    1374     if validated_v is None and should_raise:
# -> 1375         self.raise_invalid_val(v)
#    1377     v = validated_v
#    1379 return v
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/_plotly_utils/basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker
#         Received value: 'issueType'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to bar.marker.colorscale
#       - A list or array of any of the above

# %%
df_groupby_date_issueType['year'] = pd.to_datetime(df_groupby_date_issueType['date']).dt.to_period('Y')
# by_month.index = pd.PeriodIndex(by_month.index)

# df_month = by_month.rename_axis('month').reset_index(name='counts')
df_groupby_date_issueType_new = df_groupby_date_issueType.groupby(by=["year", "issueType"]).aggregate({"fundsLost":"sum"}).reset_index()

# %%
df_groupby_date_issueType_new.head()
# Out:
#    year       issueType   fundsLost
# 0  2011  Access Control      236000
# 1  2011           Other     8879420
# 2  2011         Rugpull      669900
# 3  2012  Access Control      443300
# 4  2012           Other  3360619200

# %%
fig = px.bar(df_groupby_date_issueType, x="year", y="fundsLost", color="issueType" ,title="Long-Form Input")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[271], line 2
#       1 fig = px.bar(df_groupby_date_issueType, x="year", y="fundsLost", color="issueType" ,title="Long-Form Input")
# ----> 2 fig.show()
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/io/_renderers.py:388, in show(fig, renderer, validate, **kwargs)
#     385 fig_dict = validate_coerce_fig_to_dict(fig, validate)
#     387 # Mimetype renderers
# --> 388 bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     389 if bundle:
#     390     if not ipython_display:
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/io/_renderers.py:296, in RenderersConfig._build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     293             if hasattr(renderer, k):
#     294                 setattr(renderer, k, v)
# --> 296         bundle.update(renderer.to_mimebundle(fig_dict))
#     298 return bundle
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/io/_base_renderers.py:95, in PlotlyRenderer.to_mimebundle(self, fig_dict)
#      91 if config:
#      92     fig_dict["config"] = config
#      94 json_compatible_fig_dict = json.loads(
# ---> 95     to_json(fig_dict, validate=False, remove_uids=False)
#      96 )
#      98 return {"application/vnd.plotly.v1+json": json_compatible_fig_dict}
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/io/_json.py:199, in to_json(fig, validate, pretty, remove_uids, engine)
#     196     for trace in fig_dict.get("data", []):
#     197         trace.pop("uid", None)
# --> 199 return to_json_plotly(fig_dict, pretty=pretty, engine=engine)
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/plotly/io/_json.py:123, in to_json_plotly(plotly_object, pretty, engine)
#     119         opts["separators"] = (",", ":")
#     121     from _plotly_utils.utils import PlotlyJSONEncoder
# --> 123     return json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts)
#     124 elif engine == "orjson":
#     125     JsonConfig.validate_orjson()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/_plotly_utils/utils.py:59, in PlotlyJSONEncoder.encode(self, o)
#      52 """
#      53 Load and then dump the result using parse_constant kwarg
#      54
#      55 Note that setting invalid separators will cause a failure at this step.
#      56
#      57 """
#      58 # this will raise errors in a normal-expected way
# ---> 59 encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#      60 # Brute force guessing whether NaN or Infinity values are in the string
#      61 # We catch false positive cases (e.g. strings such as titles, labels etc.)
#      62 # but this is ok since the intention is to skip the decoding / reencoding
#      63 # step when it's completely safe
#      65 if not ("NaN" in encoded_o or "Infinity" in encoded_o):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File ~/projects_KK/defiyield/venv/lib/python3.9/site-packages/_plotly_utils/utils.py:136, in PlotlyJSONEncoder.default(self, obj)
#     134     except NotEncodable:
#     135         pass
# --> 136 return _json.JSONEncoder.default(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type Period is not JSON serializable

# %%
fig = go.Figure(data=go.Bar(x=df_groupby_date_issueType_new['year'].astype(dtype=str), 
                        y=df_groupby_date_issueType_new['fundsLost'],
                        marker_color='indianred', text="counts"))

fig.update_layout({"title": 'Tweets about Malioboro from Jan 2020 to Jan 2021',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total tweets"},
                   "showlegend": False})
# fig.write_image("by-month-bar.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
# df = px.data.gapminder().query("continent=='Oceania'")
fig = px.line(df_groupby_date_issueType, x="date", y="fundsLost", color='issueType')
fig.show()

# %%
df.head()
# Out:
#       country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 60  Australia   Oceania  1952    69.12   8691212  10039.59564       AUS
# 61  Australia   Oceania  1957    70.33   9712569  10949.64959       AUS
# 62  Australia   Oceania  1962    70.93  10794968  12217.22686       AUS
# 63  Australia   Oceania  1967    71.10  11872264  14526.12465       AUS
# 64  Australia   Oceania  1972    71.93  13177000  16788.62948       AUS
#
#     iso_num
# 60       36
# 61       36
# 62       36
# 63       36
# 64       36

# %%
list_of_categories = df_rects.category.unique()

# %%
res = [i for i in list_of_categories if i is not None]

# %%
sorted_list = sorted(res, key=lambda x: x[0])

# %%
sorted_list[20:]
# Out:
# ['Gaming / Metaverse,Token',
#  'Gaming / Metaverse',
#  'NFT,Token',
#  'NFT,Other',
#  'NFT',
#  'Other',
#  'Other,Token',
#  'Other,Yield Aggregator',
#  'Stablecoin',
#  'Stablecoin,Yield Aggregator',
#  'Token,Yield Aggregator',
#  'Token',
#  'Yield Aggregator']

# %%
x = df_rects.issueType.unique()

# %%
x.sort()

# %%
x
# Out:
# array(['Abandoned', 'Access Control', 'Flash Loan Attack', 'Honeypot',
#        'Oracle Issue', 'Other', 'Phishing', 'Reentrancy', 'Rugpull'],
#       dtype=object)
